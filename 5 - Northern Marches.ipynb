# %%
from source.regency import Regency
from source.mapping import Mapping
# %matplotlib notebook
Game = Regency('Birthright')
# Out:
# Using TensorFlow backend.
# WARNING:tensorflow:From C:\Users\darin\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\darin\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# %matplotlib notebook

# %% [markdown]
# ### Dhoesone

# %%
Region = 'The Northern Marches'
d = 'Dhoesone'
p = 'Bjondrig'
Game.add_provence(p, d, Region, 'FD', Population=1, Magic=4, x=820, y=1265, Waterway=True)
Game.add_holding(p, 'SH', 'Law', 1)
Game.add_holding(p, 'FD', 'Law', 0)
p = 'Dharilen'
Game.add_provence(p, d, Region, 'FD', Population=1, Magic=4, x=1090, y=1120, Waterway=True, Terrain='Hills')
Game.add_holding(p, 'FD', 'Law', 1)
Game.add_holding(p, 'AD', 'Law', 0)
p = "Giant's Fastness"
Game.add_provence(p, d, Region, 'FD', Population=1, Magic=4, x=1145, y=1195, Terrain='Hills', Waterway=True)
Game.add_holding(p, 'GTh', 'Law', 1)
Game.add_holding(p, 'FD', 'Law', 0)
Game.add_geo(p, 'Dharilen', Border=1)
p = 'Hidaele'
Game.add_provence(p, d, Region, 'FD', Population=2, Magic=3, x=1130, y=1300, Waterway=True)

Game.add_geo(p, "Giant's Fastness", Border=1)
Game.add_holding(p, 'FD', 'Law', 1)
Game.add_holding(p, 'BA', 'Law', 0)
p = 'Nolien'
Game.add_provence(p, d, Region, 'FD', Population=3, Magic=2, x=910, y=1350, Waterway=True)
Game.add_geo(p, 'Bjondrig', Border=1)
Game.add_holding(p, 'FD', 'Law', 2)
Game.add_holding(p, 'SH', 'Law', 0)
p = 'Riverside'
Game.add_provence(p, d, Region, 'FD', Population=2, Magic=3, x=890, y=1225, Waterway=True)
Game.add_geo(p, 'Bjondrig', Border=1)
Game.add_geo(p, 'Nolien', Border=1)
Game.add_holding(p, 'FD', 'Law', 1)
Game.add_holding(p, 'SH', 'Law', 0)
p = 'Romiene'
Game.add_provence(p, d, Region, 'FD', Population=1, Magic=4, x=955, y=1180, Waterway=True)


Game.add_geo(p, 'Riverside', Border=1)
Game.add_holding(p, 'FD', 'Law', 0)
Game.add_holding(p, 'BA', 'Law', 1)
p = 'Ruidewash'
Game.add_provence(p, d, Region, 'FD', Population=2, Magic=5, x=1085, y=1365, Terrain='Forest', Waterway=True)
Game.add_geo(p, 'Hidaele', Border=1)
Game.add_holding(p, 'FD', 'Law', 1)
Game.add_holding(p, 'AD', 'Law', 0)
p = 'Sidhuire'
Game.add_provence(p, d, Region, 'FD', Population=2, Magic=5, x=1030, y=1180, Waterway=True, Terrain='Forest')
Game.add_geo(p, "Giant's Fastness", Border=1)
Game.add_geo(p, 'Romiene', Border=1)
Game.add_geo(p, 'Dharilen', Border=1)
Game.add_holding(p, 'FD', 'Law', 1)
Game.add_holding(p, 'AD', 'Law', 0)
p = 'Soniele'
Game.add_provence(p, d, Region, 'FD', Population=1, Magic=6, x=1070, y=1240, Terrain='Forest')
Game.add_geo(p, 'Hidaele', Border=1)
Game.add_geo(p, "Giant's Fastness", Border=1)
Game.add_geo(p, 'Sidhuire', Border=1)
Game.add_geo(p, 'Romiene', Border=1)
Game.add_holding(p, 'GTh', 'Law', 1)
Game.add_holding(p, 'FD', 'Law', 0)
p = 'Sonnelind'
Game.add_provence(p, d, Region, 'FD', Population=4, Magic=3, x=1025, y=1305, Terrain='Forest', Capital=True)
Game.add_geo(p, 'Nolien', Border=1)
Game.add_geo(p, 'Ruidewash', Border=1)
Game.add_geo(p, 'Soniele', Border=1)
Game.add_geo(p, 'Romiene', Border=1)
Game.add_geo(p, 'Riverside', Border=1)
Game.add_holding(p, 'MB', 'Law', 1)
Game.add_holding(p, 'FD', 'Law', 3)
p = 'Tradebhein'
Game.add_provence(p, d, Region, 'FD', Population=2, Magic=5, x=1000, y=1395, Waterway=True, Terrain='Forest')
Game.add_geo(p, 'Nolien', Border=1)
Game.add_geo(p, 'Sonnelind', Border=1)
Game.add_geo(p, 'Ruidewash', Border=1)
Game.add_holding(p, 'MB', 'Law', 0)
Game.add_holding(p, 'FD', 'Law', 1)

# %%
#Game.save_world('Birthright')
maps = Mapping(Game)
maps.focus_regions([Region])
# maps.focus_regents(['AB'])
#maps.focus_domains(['Boeruine', 'Avanil', 'Brosengae', 'Tuornen', 'Rhuobhe', 'Taeghas'])
maps.show(show_abbreviations=True, show_troops=True, line_len=90, borders=True)
# Out:
# <img src="data:image/png;base64,..." width="999.9999628438592">
# C:\Users\darin\Anaconda3\lib\site-packages\networkx\drawing\nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# MB
# AD
# SH
# BA
# GTh
# FD

# %%
Game.add_regent('CJS', 'Celestial Jewel of Sarimie (Temais Coumain)', Archetype='Priest')

Game.add_regent('CSH', "Church of Storm's End", Archetype='Priest')
Game.add_regent('TCV', 'One True Church of Vosgaard', Archetype='Priest')
Game.add_regent('EM', "Rriene Mierelen (Brosen Royal Guild)")
Game.add_regent('AV', "Arron Vaumel (Straits of Aerele Shipping)", Archetype='Mage')



Game.add_regent('TF', 'The Fortress (Tugaere Issimane)', Archetype='Priest')
Game.add_regent('WB', "Water's Blessing (Phisiad Uriene)", Archetype='Priest')
Game.add_regent('MOC', "Militant Order of Cuiraecen (Fhylie the Sword)", Archetype='Priest')
Game.add_regent('GTh', "Gaelin Thuried (Upper Anuire Traders)")

Game.add_regent('MB', "Mheallie Bireon (Stonecrown Coster, Source of the Maesil, Northlands Exchange)")

Game.add_regent('EL', "Elamien Lamier (Points East Trading Guild)")
Game.add_regent('HA', "Haelyn's Aegis (Anita Maricoere)", Archetype='Priest')

# %%
Game.Regents[Game.Regents['Regent']=='AD']
# Out:
# Empty DataFrame
# Columns: [Regent, Full Name, Bloodline, Culture, Player, Class, Level, Alignment, Race, Str, Dex, Con, Int, Wis, Cha, Insight, Deception, Persuasion, Regency Points, Gold Bars, Regency Bonus, Attitude, Alive, Divine, Arcane]
# Index: []
#
# [0 rows x 25 columns]
